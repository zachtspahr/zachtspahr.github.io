# %%
import tweepy
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()
import json
from config_twitter import consumer_key, consumer_secret, access_token, access_token_secret
import time
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth,parser=tweepy.parsers.JSONParser())

# %%
file_one = pd.read_csv("CD Demographics.csv")

file_one ["White"] = file_one ["White"] / file_one ["Total population"]
file_one ["Black or African American"] = file_one ["Black or African American"] / file_one ["Total population"]
file_one ["Asian"] = file_one ["Asian"] / file_one ["Total population"]
file_one ["Hispanic or Latino (of any race)"] = file_one ["Hispanic or Latino (of any race)"] / file_one ["Total population"]
file_one.head()
# Out:
#   District  Total population  Median age (years)  18 years and over  \
# 0    VA-01            813878                38.6             619403
# 1    VA-02            743410                36.2             585280
# 2    VA-03            744804                34.9             577378
# 3    VA-04            747291                38.7             596774
# 4    VA-05            739410                42.8             594390
#
#    65 years and over  One race     White  Black or African American     Asian  \
# 0             123912    779581  0.720108                   0.162924  0.033579
# 1             112245    706976  0.661321                   0.201558  0.059495
# 2             100426    711396  0.443331                   0.457361  0.029615
# 3             115128    724861  0.528882                   0.410429  0.017692
# 4             150340    714747  0.749319                   0.190252  0.019800
#
#    Some other race  ...  Cuban  Other Hispanic or Latino  \
# ...

# %%
file_one.iloc[:,0:15]
# Out:
#    District  Total population  Median age (years)  18 years and over  \
# 0     VA-01            813878                38.6             619403
# 1     VA-02            743410                36.2             585280
# 2     VA-03            744804                34.9             577378
# 3     VA-04            747291                38.7             596774
# 4     VA-05            739410                42.8             594390
# 5     VA-06            755437                39.9             603009
# 6     VA-07            812385                39.3             622337
# 7     VA-08            795467                36.2             629953
# 8     VA-09            704831                43.5             576130
# 9     VA-10            862308                38.4             634862
# 10    VA-11            798464                36.7             608529
#
#     65 years and over  One race     White  Black or African American  \
# ...

# %%
list_dfs = []
for i in range(len(file_one["District"])):
    cd_df = file_one.iloc[i,:]
    new_df = pd.DataFrame(cd_df)
    new_df = new_df.reset_index()
    new_df = new_df.rename(columns={"index": "Category", 1: "District Characteristics"})
    list_dfs.append(new_df)
list_dfs[0]
# Out:
#                              Category       0
# 0                            District   VA-01
# 1                    Total population  813878
# 2                  Median age (years)    38.6
# 3                   18 years and over  619403
# 4                   65 years and over  123912
# 5                            One race  779581
# 6                               White  586080
# 7           Black or African American  132600
# 8                               Asian   27329
# 9                     Some other race   30862
# 10                  Two or more races   34297
# 11   Hispanic or Latino (of any race)   97345
# 12                            Mexican   20761
# 13                       Puerto Rican   13455
# 14                              Cuban    2343
# 15           Other Hispanic or Latino   60786
# 16             Not Hispanic or Latino  716533
# 17                             Native  738726
# 18              Born in United States  720234
# ...

# %%
html_list = []
for df in list_dfs:
    new_df = df.to_html()
    df.to_html(f'{df.iloc[0,1]}_demographics.html',table_id= {df.iloc[0,1]})
    html_list.append(new_df)
html_list[0]
